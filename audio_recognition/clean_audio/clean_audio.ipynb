# %%
import os

if not os.path.exists('thinkdsp.py'):
   # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Out:
# --2024-10-20 13:07:55--  https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py [following]
# --2024-10-20 13:07:55--  https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48574 (47K) [text/plain]
# Saving to: ‘thinkdsp.py’
#
# thinkdsp.py         100%[===================>]  47.44K  --.-KB/s    in 0.008s
#
# 2024-10-20 13:07:55 (5.84 MB/s) - ‘thinkdsp.py’ saved [48574/48574]

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece1-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece2-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece3-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece4-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece5-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece6-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece7-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece8-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece9-Trimmed by FlexClip.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-d426df9e6aef> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece9-Trimmed by FlexClip.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece10-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece11-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece12-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece13-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece14-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece15-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece16-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece17-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece18-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece19-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece20-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece1-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece1-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece1-Trimmed by FlexClip.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece1-Trimmed by FlexClip.wav')

myVoice.plot()
