# %% [markdown]
# <a href="https://colab.research.google.com/github/dacles22/dsp/blob/main/audio_recognition/100ece.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

if not os.path.exists('thinkdsp.py'):
   # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Out:
# --2024-10-10 21:49:28--  https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py [following]
# --2024-10-10 21:49:28--  https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48574 (47K) [text/plain]
# Saving to: ‘thinkdsp.py’
#
# thinkdsp.py         100%[===================>]  47.44K  --.-KB/s    in 0.01s
#
# 2024-10-10 21:49:28 (3.82 MB/s) - ‘thinkdsp.py’ saved [48574/48574]

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece1.wav.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece2.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece3.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece4.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece5.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece6.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece7.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece8.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece11.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece12.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece9.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece10.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece13.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece14.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece15.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece16.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece17.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece18.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece19.wav')
spec = myVoice.make_spectrum()
spec.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-379f29bbacdd> in <cell line: 3>()
#       1 from thinkdsp import read_wave
#       2
# ----> 3 myVoice = read_wave('ece19.wav')
#       4 spec = myVoice.make_spectrum()
#       5 spec.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece20.wav')
spec = myVoice.make_spectrum()
spec.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-2905b056ce53> in <cell line: 3>()
#       1 from thinkdsp import read_wave
#       2
# ----> 3 myVoice = read_wave('ece20.wav')
#       4 spec = myVoice.make_spectrum()
#       5 spec.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece20.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece21.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece5.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece22.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece23.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece24.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece25.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece26.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece27.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece28.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece29.wav')
spec = myVoice.make_spectrum()
spec.plot()

# %%
from thinkdsp import read_wave

myVoice = read_wave('ece30.wav')
spec = myVoice.make_spectrum()
spec.plot()
