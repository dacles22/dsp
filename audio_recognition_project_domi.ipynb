# %% [markdown]
# <a href="https://colab.research.google.com/github/dacles22/dsp/blob/main/audio_recognition_project_domi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

if not os.path.exists('thinkdsp.py'):
   # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Out:
# --2024-10-17 10:41:20--  https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py [following]
# --2024-10-17 10:41:20--  https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48574 (47K) [text/plain]
# Saving to: ‘thinkdsp.py’
#
# thinkdsp.py         100%[===================>]  47.44K  --.-KB/s    in 0.01s
#
# 2024-10-17 10:41:20 (4.23 MB/s) - ‘thinkdsp.py’ saved [48574/48574]

# %%
import librosa
import numpy as np
import soundfile as sf

# Load the audio file
audio, sample_rate = librosa.load('ece1.wav', sr=44100)

# Find the index of the first positive sample
first_positive_index = np.where(audio > 0.50)[0]

# Check if there's a positive sample
if first_positive_index.size > 0:
    # Crop the audio from the first positive sample to 44099 samples
    start_index = first_positive_index[0]
    cropped_audio = audio[start_index:start_index + 44100]

    # Ensure we don't exceed the array length
    if len(cropped_audio) < 44099:
        print("Not enough samples to crop to 44099.")
    else:
        # Write the cropped audio to a new file
        sf.write('clean_ece1.wav', cropped_audio, sample_rate, subtype='PCM_24')
else:
    print("No positive samples found in the audio.")
# Out:
# No positive samples found in the audio.

# %%
import librosa

# Load the audio file
audio, sample_rate = librosa.load('ece1.wav', sr=44100)

# Get the number of samples
num_samples = len(audio)

print(f"Number of samples: {num_samples}")
# Out:
# Number of samples: 272832

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece1.wav')

myVoice.plot()

# %%
import librosa
import numpy as np
import soundfile as sf

# Load the audio file
audio, sample_rate = librosa.load('ece2.wav', sr=44100)

# Find the index of the first positive sample
first_positive_index = np.where(audio > 0.75)[0]

# Check if there's a positive sample
if first_positive_index.size > 0:
    # Crop the audio from the first positive sample to 44099 samples
    start_index = first_positive_index[0]
    cropped_audio = audio[start_index:start_index + 44100]

    # Ensure we don't exceed the array length
    if len(cropped_audio) < 44099:
        print("Not enough samples to crop to 44099.")
    else:
        # Write the cropped audio to a new file
        sf.write('ece2.wav', cropped_audio, sample_rate, subtype='PCM_24')
else:
    print("No positive samples found in the audio.")
# Out:
# No positive samples found in the audio.

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece2.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece3.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece4.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece5.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece6.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece7.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece8.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece9.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece10.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece11.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece12.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece13.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece14.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece15.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece16.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece17.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece18.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece19.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece20.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-12716b9ebbf0> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece20.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece21.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-57-4d9ca29c81ed> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece21.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece22.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-e491516ac602> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece22.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece23.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-a7c19b467b26> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece23.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece24.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece25.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-ca1427bbc909> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece25.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece26.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-01a130e25aad> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece26.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece27.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-4a6a5192bf7d> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece27.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece28.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-59e934e4571b> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece28.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece29.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-c8dfce14d9fa> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece29.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece30.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-c1012d701387> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece30.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece31.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece32.wav')

myVoice.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-ada11b9d0f8a> in <cell line: 2>()
#       1 from thinkdsp import read_wave
# ----> 2 myVoice = read_wave('ece32.wav')
#       3
#       4 myVoice.plot()
#
# /content/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.10/wave.py in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /usr/lib/python3.10/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
# ...

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece33.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece34.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece35.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece36.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece37.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece38.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece39.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece40.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece41.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece42.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece43.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece44.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece45.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece46.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece47.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece48.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece49.wav')

myVoice.plot()

# %%
from thinkdsp import read_wave
myVoice = read_wave('ece50.wav')

myVoice.plot()
